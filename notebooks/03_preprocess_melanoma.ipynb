# %%
import pandas as pd
import scanpy as sc

# %%
df = pd.read_csv("../data/raw/melanoma/GSE72056_melanoma_single_cell_revised_v2.txt.gz", sep='\t', index_col=0)
expr = df.iloc[:, :-1].T
labels = df.iloc[-1, :-1]  # last row: cell types

df
# Out:
#                                                     Cy72_CD45_H02_S758_comb  \
# Cell
# tumor                                                               72.0000
# malignant(1=no,2=yes,0=unresolved)                                   1.0000
# non-malignant cell type (1=T,2=B,3=Macro.4=Endo...                   2.0000
# C9orf152                                                             0.0000
# RPS11                                                                9.2172
# ...                                                                     ...
# PIK3IP1                                                              7.6069
# SNRPD2                                                               0.0000
# SLC39A6                                                              0.0000
# CTSC                                                                 2.6638
# AQP7                                                                 0.0000
#
# ...

# %%
expr
# Out:
# Cell                          tumor  malignant(1=no,2=yes,0=unresolved)  \
# Cy72_CD45_H02_S758_comb        72.0                                 1.0
# CY58_1_CD45_B02_S974_comb      58.0                                 1.0
# Cy71_CD45_D08_S524_comb        71.0                                 2.0
# Cy81_FNA_CD45_B01_S301_comb    81.0                                 2.0
# Cy80_II_CD45_B07_S883_comb     80.0                                 2.0
# ...                             ...                                 ...
# CY75_1_CD45_CD8_1__S25_comb    75.0                                 1.0
# CY75_1_CD45_CD8_7__S223_comb   75.0                                 1.0
# CY75_1_CD45_CD8_1__S65_comb    75.0                                 1.0
# CY75_1_CD45_CD8_1__S93_comb    75.0                                 1.0
# CY75_1_CD45_CD8_1__S76_comb    75.0                                 1.0
#
# Cell                          non-malignant cell type (1=T,2=B,3=Macro.4=Endo.,5=CAF;6=NK)  \
# ...

# %%
labels.values
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], shape=(4644,))

# %%
adata = sc.AnnData(expr)
#adata.obs['cell_type'] = labels.values
sc.pp.filter_genes(adata, min_cells=3)
sc.pp.normalize_total(adata)
sc.pp.log1p(adata)
#adata.write("../data/processed/melanoma.h5ad")
# Out:
# /pscratch/lji226_uksr/DMNN/.dtnn_env/lib/python3.13/site-packages/anndata/_core/anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /pscratch/lji226_uksr/DMNN/.dtnn_env/lib/python3.13/site-packages/anndata/_core/anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /pscratch/lji226_uksr/DMNN/.dtnn_env/lib/python3.13/site-packages/anndata/_core/anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
adata.shape
# Out:
# (4644, 22292)
